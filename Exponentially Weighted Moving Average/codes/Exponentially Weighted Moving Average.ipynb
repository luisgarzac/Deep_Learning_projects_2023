# %% [markdown]
# # Exponentially Weighted Moving Average

# %% [markdown]
# ## Lectura y representación del conjunto de datos

# %%
import pandas as pd

df = pd.read_csv("/Users/Luis Antonio Garza/Machine_Learning/curso_deeplearning/notebooks_curso/Exponentially+weighted+moving+average.ipynb/weather_Madrid.csv")
df
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0       1997-1-1               7.0                4.0               2.0
# 1       1997-1-2               7.0                3.0               0.0
# 2       1997-1-3               5.0                3.0               2.0
# 3       1997-1-4               7.0                3.0              -1.0
# 4       1997-1-5               2.0                0.0              -1.0
# ...          ...               ...                ...               ...
# 6807  2015-12-27              14.0                7.0              -1.0
# 6808  2015-12-28              15.0                8.0               2.0
# 6809  2015-12-29              11.0                8.0               5.0
# 6810  2015-12-30               9.0                8.0               6.0
# 6811  2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 0            5.0             3.0            2.0         100.0            95.0
# 1            6.0             3.0            0.0         100.0            92.0
# 2            5.0             1.0           -1.0         100.0            85.0
# 3           -2.0            -3.0           -4.0          86.0            63.0
# 4            2.0             0.0           -3.0         100.0            95.0
# ...          ...             ...            ...           ...             ...
# 6807         6.0             2.0           -2.0         100.0            77.0
# 6808         8.0             4.0            1.0         100.0            78.0
# 6809         9.0             7.0            5.0         100.0            89.0
# 6810         7.0             6.0            5.0          93.0            87.0
# 6811        10.0             8.0            7.0         100.0            90.0
#
#        Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# 0              76.0  ...               10.0                 9.0
# 1              71.0  ...               10.0                 9.0
# 2              70.0  ...               10.0                10.0
# 3              49.0  ...               10.0                10.0
# 4              86.0  ...               10.0                 5.0
# ...             ...  ...                ...                 ...
# 6807           30.0  ...               31.0                14.0
# 6808           34.0  ...               31.0                14.0
# 6809           66.0  ...               31.0                 9.0
# 6810           70.0  ...               19.0                10.0
# 6811           70.0  ...               31.0                 8.0
#
#        Min VisibilitykM   Max Wind SpeedKm/h   Mean Wind SpeedKm/h  \
# 0                   4.0                   13                     6
# 1                   4.0                   26                     8
# 2                   7.0                   27                    19
# 3                  10.0                   27                    19
# 4                   1.0                   14                     6
# ...                 ...                  ...                   ...
# 6807                5.0                   14                     6
# 6808                8.0                   27                     8
# 6809                0.0                   14                     8
# 6810                6.0                   14                     5
# 6811                2.0                   14                     6
#
#        Max Gust SpeedKm/h  Precipitationmm   CloudCover     Events  \
# 0                     NaN             0.00          6.0        NaN
# 1                    47.0             0.00          5.0       Rain
# 2                     NaN             0.00          6.0  Rain-Snow
# 3                    40.0             0.00          2.0        NaN
# 4                     NaN             0.00          7.0       Snow
# ...                   ...              ...          ...        ...
# 6807                  NaN             0.00          8.0        Fog
# 6808                 45.0             0.51          7.0       Rain
# 6809                 32.0             2.03          5.0   Fog-Rain
# 6810                 34.0             0.00          6.0        NaN
# 6811                  NaN             0.25          6.0       Rain
#
#       WindDirDegrees
# 0                229
# 1                143
# 2                256
# 3                284
# 4                  2
# ...              ...
# 6807              38
# 6808             243
# 6809             190
# 6810             256
# 6811             313
#
# [6812 rows x 23 columns]

# %%
# Tranformamos la columna CET a formato fecha para comparar
df["CET"] = pd.to_datetime(df["CET"])

# %%
# creamos el filtro que queremos aplicar al conjunto de datos
mask = (df['CET'] >= '2015-1-1') & (df['CET'] <= '2015-12-31')

# %%
df_prep = df.loc[mask][["CET", "Mean TemperatureC"]]
df_prep
# Out:
#             CET  Mean TemperatureC
# 6447 2015-01-01                3.0
# 6448 2015-01-02                3.0
# 6449 2015-01-03                4.0
# 6450 2015-01-04                7.0
# 6451 2015-01-05                6.0
# ...         ...                ...
# 6807 2015-12-27                7.0
# 6808 2015-12-28                8.0
# 6809 2015-12-29                8.0
# 6810 2015-12-30                8.0
# 6811 2015-12-31               10.0
#
# [365 rows x 2 columns]

# %%
# Representación grafica del conjunto de datos
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.figure(figsize = (22,11))
plt.plot(df_prep["CET"], df_prep["Mean TemperatureC"], "bo")

plt.ylabel("Temperatura", fontsize = 14)
plt.xticks(['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01'], fontsize=11)
plt.yticks(fontsize = 14)
plt.grid()

plt.show()

# %%
# Representacion grafica del conjunto de datos
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.figure(figsize=(14, 7))
plt.plot(df_prep["CET"], df_prep["Mean TemperatureC"], "b")

plt.ylabel("Temperatura", fontsize=12)
plt.xticks(['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01'], fontsize=11)
plt.yticks(fontsize=11)
plt.grid()

plt.show()

# %% [markdown]
# # Técnica de exponentially weighted moving average

# %%
# calculamos la técnica
def ewma(theta, b = 0.9):
    if len(theta) ==1:
        return b*0 + (1-b)*theta[-1]
    return b*ewma(theta[:-1]) + (1-b)*theta[-1]

# %%
import numpy as np

def apply_ewma(data, b=0.9):
    v_data = []
    for i in np.arange(1, len(data) + 1):
        print("\nProcesando ejemplo: {0}".format(i), end='')
        v_data.append(ewma(data[:i], b = b))
    return v_data

# %%
v_df = apply_ewma(list(df_prep["Mean TemperatureC"]))
# Out:
# Procesando ejemplo: 1
# Procesando ejemplo: 2
# Procesando ejemplo: 3
# Procesando ejemplo: 4
# Procesando ejemplo: 5
# Procesando ejemplo: 6
# Procesando ejemplo: 7
# Procesando ejemplo: 8
# Procesando ejemplo: 9
# Procesando ejemplo: 10
# Procesando ejemplo: 11
# Procesando ejemplo: 12
# Procesando ejemplo: 13
# Procesando ejemplo: 14
# Procesando ejemplo: 15
# Procesando ejemplo: 16
# Procesando ejemplo: 17
# Procesando ejemplo: 18
# Procesando ejemplo: 19
# Procesando ejemplo: 20
# Procesando ejemplo: 21
# Procesando ejemplo: 22
# Procesando ejemplo: 23
# Procesando ejemplo: 24
# Procesando ejemplo: 25
# Procesando ejemplo: 26
# Procesando ejemplo: 27
# Procesando ejemplo: 28
# Procesando ejemplo: 29
# Procesando ejemplo: 30
# Procesando ejemplo: 31
# Procesando ejemplo: 32
# Procesando ejemplo: 33
# Procesando ejemplo: 34
# Procesando ejemplo: 35
# Procesando ejemplo: 36
# Procesando ejemplo: 37
# Procesando ejemplo: 38
# Procesando ejemplo: 39
# Procesando ejemplo: 40
# Procesando ejemplo: 41
# Procesando ejemplo: 42
# Procesando ejemplo: 43
# Procesando ejemplo: 44
# Procesando ejemplo: 45
# Procesando ejemplo: 46
# Procesando ejemplo: 47
# Procesando ejemplo: 48
# Procesando ejemplo: 49
# Procesando ejemplo: 50
# Procesando ejemplo: 51
# Procesando ejemplo: 52
# Procesando ejemplo: 53
# Procesando ejemplo: 54
# Procesando ejemplo: 55
# Procesando ejemplo: 56
# Procesando ejemplo: 57
# Procesando ejemplo: 58
# Procesando ejemplo: 59
# Procesando ejemplo: 60
# Procesando ejemplo: 61
# Procesando ejemplo: 62
# Procesando ejemplo: 63
# Procesando ejemplo: 64
# Procesando ejemplo: 65
# Procesando ejemplo: 66
# Procesando ejemplo: 67
# Procesando ejemplo: 68
# Procesando ejemplo: 69
# Procesando ejemplo: 70
# Procesando ejemplo: 71
# Procesando ejemplo: 72
# Procesando ejemplo: 73
# Procesando ejemplo: 74
# Procesando ejemplo: 75
# Procesando ejemplo: 76
# Procesando ejemplo: 77
# Procesando ejemplo: 78
# Procesando ejemplo: 79
# Procesando ejemplo: 80
# Procesando ejemplo: 81
# Procesando ejemplo: 82
# Procesando ejemplo: 83
# Procesando ejemplo: 84
# Procesando ejemplo: 85
# Procesando ejemplo: 86
# Procesando ejemplo: 87
# Procesando ejemplo: 88
# Procesando ejemplo: 89
# Procesando ejemplo: 90
# Procesando ejemplo: 91
# Procesando ejemplo: 92
# Procesando ejemplo: 93
# Procesando ejemplo: 94
# Procesando ejemplo: 95
# Procesando ejemplo: 96
# Procesando ejemplo: 97
# Procesando ejemplo: 98
# Procesando ejemplo: 99
# Procesando ejemplo: 100
# Procesando ejemplo: 101
# Procesando ejemplo: 102
# Procesando ejemplo: 103
# Procesando ejemplo: 104
# Procesando ejemplo: 105
# Procesando ejemplo: 106
# Procesando ejemplo: 107
# Procesando ejemplo: 108
# Procesando ejemplo: 109
# Procesando ejemplo: 110
# Procesando ejemplo: 111
# Procesando ejemplo: 112
# Procesando ejemplo: 113
# Procesando ejemplo: 114
# Procesando ejemplo: 115
# Procesando ejemplo: 116
# Procesando ejemplo: 117
# Procesando ejemplo: 118
# Procesando ejemplo: 119
# Procesando ejemplo: 120
# Procesando ejemplo: 121
# Procesando ejemplo: 122
# Procesando ejemplo: 123
# Procesando ejemplo: 124
# Procesando ejemplo: 125
# Procesando ejemplo: 126
# Procesando ejemplo: 127
# Procesando ejemplo: 128
# Procesando ejemplo: 129
# Procesando ejemplo: 130
# Procesando ejemplo: 131
# Procesando ejemplo: 132
# Procesando ejemplo: 133
# Procesando ejemplo: 134
# Procesando ejemplo: 135
# Procesando ejemplo: 136
# Procesando ejemplo: 137
# Procesando ejemplo: 138
# Procesando ejemplo: 139
# Procesando ejemplo: 140
# Procesando ejemplo: 141
# Procesando ejemplo: 142
# Procesando ejemplo: 143
# Procesando ejemplo: 144
# Procesando ejemplo: 145
# Procesando ejemplo: 146
# Procesando ejemplo: 147
# Procesando ejemplo: 148
# Procesando ejemplo: 149
# Procesando ejemplo: 150
# Procesando ejemplo: 151
# Procesando ejemplo: 152
# Procesando ejemplo: 153
# Procesando ejemplo: 154
# Procesando ejemplo: 155
# Procesando ejemplo: 156
# Procesando ejemplo: 157
# Procesando ejemplo: 158
# Procesando ejemplo: 159
# Procesando ejemplo: 160
# Procesando ejemplo: 161
# Procesando ejemplo: 162
# Procesando ejemplo: 163
# Procesando ejemplo: 164
# Procesando ejemplo: 165
# Procesando ejemplo: 166
# Procesando ejemplo: 167
# Procesando ejemplo: 168
# Procesando ejemplo: 169
# Procesando ejemplo: 170
# Procesando ejemplo: 171
# Procesando ejemplo: 172
# Procesando ejemplo: 173
# Procesando ejemplo: 174
# Procesando ejemplo: 175
# Procesando ejemplo: 176
# Procesando ejemplo: 177
# Procesando ejemplo: 178
# Procesando ejemplo: 179
# Procesando ejemplo: 180
# Procesando ejemplo: 181
# Procesando ejemplo: 182
# Procesando ejemplo: 183
# Procesando ejemplo: 184
# Procesando ejemplo: 185
# Procesando ejemplo: 186
# Procesando ejemplo: 187
# Procesando ejemplo: 188
# Procesando ejemplo: 189
# Procesando ejemplo: 190
# Procesando ejemplo: 191
# Procesando ejemplo: 192
# Procesando ejemplo: 193
# Procesando ejemplo: 194
# Procesando ejemplo: 195
# Procesando ejemplo: 196
# Procesando ejemplo: 197
# Procesando ejemplo: 198
# Procesando ejemplo: 199
# Procesando ejemplo: 200
# Procesando ejemplo: 201
# Procesando ejemplo: 202
# Procesando ejemplo: 203
# Procesando ejemplo: 204
# Procesando ejemplo: 205
# Procesando ejemplo: 206
# Procesando ejemplo: 207
# Procesando ejemplo: 208
# Procesando ejemplo: 209
# Procesando ejemplo: 210
# Procesando ejemplo: 211
# Procesando ejemplo: 212
# Procesando ejemplo: 213
# Procesando ejemplo: 214
# Procesando ejemplo: 215
# Procesando ejemplo: 216
# Procesando ejemplo: 217
# Procesando ejemplo: 218
# Procesando ejemplo: 219
# Procesando ejemplo: 220
# Procesando ejemplo: 221
# Procesando ejemplo: 222
# Procesando ejemplo: 223
# Procesando ejemplo: 224
# Procesando ejemplo: 225
# Procesando ejemplo: 226
# Procesando ejemplo: 227
# Procesando ejemplo: 228
# Procesando ejemplo: 229
# Procesando ejemplo: 230
# Procesando ejemplo: 231
# Procesando ejemplo: 232
# Procesando ejemplo: 233
# Procesando ejemplo: 234
# Procesando ejemplo: 235
# Procesando ejemplo: 236
# Procesando ejemplo: 237
# Procesando ejemplo: 238
# Procesando ejemplo: 239
# Procesando ejemplo: 240
# Procesando ejemplo: 241
# Procesando ejemplo: 242
# Procesando ejemplo: 243
# Procesando ejemplo: 244
# Procesando ejemplo: 245
# Procesando ejemplo: 246
# Procesando ejemplo: 247
# Procesando ejemplo: 248
# Procesando ejemplo: 249
# Procesando ejemplo: 250
# Procesando ejemplo: 251
# Procesando ejemplo: 252
# Procesando ejemplo: 253
# Procesando ejemplo: 254
# Procesando ejemplo: 255
# Procesando ejemplo: 256
# Procesando ejemplo: 257
# Procesando ejemplo: 258
# Procesando ejemplo: 259
# Procesando ejemplo: 260
# Procesando ejemplo: 261
# Procesando ejemplo: 262
# Procesando ejemplo: 263
# Procesando ejemplo: 264
# Procesando ejemplo: 265
# Procesando ejemplo: 266
# Procesando ejemplo: 267
# Procesando ejemplo: 268
# Procesando ejemplo: 269
# Procesando ejemplo: 270
# Procesando ejemplo: 271
# Procesando ejemplo: 272
# Procesando ejemplo: 273
# Procesando ejemplo: 274
# Procesando ejemplo: 275
# Procesando ejemplo: 276
# Procesando ejemplo: 277
# Procesando ejemplo: 278
# Procesando ejemplo: 279
# Procesando ejemplo: 280
# Procesando ejemplo: 281
# Procesando ejemplo: 282
# Procesando ejemplo: 283
# Procesando ejemplo: 284
# Procesando ejemplo: 285
# Procesando ejemplo: 286
# Procesando ejemplo: 287
# Procesando ejemplo: 288
# Procesando ejemplo: 289
# Procesando ejemplo: 290
# Procesando ejemplo: 291
# Procesando ejemplo: 292
# Procesando ejemplo: 293
# Procesando ejemplo: 294
# Procesando ejemplo: 295
# Procesando ejemplo: 296
# Procesando ejemplo: 297
# Procesando ejemplo: 298
# Procesando ejemplo: 299
# Procesando ejemplo: 300
# Procesando ejemplo: 301
# Procesando ejemplo: 302
# Procesando ejemplo: 303
# Procesando ejemplo: 304
# Procesando ejemplo: 305
# Procesando ejemplo: 306
# Procesando ejemplo: 307
# Procesando ejemplo: 308
# Procesando ejemplo: 309
# Procesando ejemplo: 310
# Procesando ejemplo: 311
# Procesando ejemplo: 312
# Procesando ejemplo: 313
# Procesando ejemplo: 314
# Procesando ejemplo: 315
# Procesando ejemplo: 316
# Procesando ejemplo: 317
# Procesando ejemplo: 318
# Procesando ejemplo: 319
# Procesando ejemplo: 320
# Procesando ejemplo: 321
# Procesando ejemplo: 322
# Procesando ejemplo: 323
# Procesando ejemplo: 324
# Procesando ejemplo: 325
# Procesando ejemplo: 326
# Procesando ejemplo: 327
# Procesando ejemplo: 328
# Procesando ejemplo: 329
# Procesando ejemplo: 330
# Procesando ejemplo: 331
# Procesando ejemplo: 332
# Procesando ejemplo: 333
# Procesando ejemplo: 334
# Procesando ejemplo: 335
# Procesando ejemplo: 336
# Procesando ejemplo: 337
# Procesando ejemplo: 338
# Procesando ejemplo: 339
# Procesando ejemplo: 340
# Procesando ejemplo: 341
# Procesando ejemplo: 342
# Procesando ejemplo: 343
# Procesando ejemplo: 344
# Procesando ejemplo: 345
# Procesando ejemplo: 346
# Procesando ejemplo: 347
# Procesando ejemplo: 348
# Procesando ejemplo: 349
# Procesando ejemplo: 350
# Procesando ejemplo: 351
# Procesando ejemplo: 352
# Procesando ejemplo: 353
# Procesando ejemplo: 354
# Procesando ejemplo: 355
# Procesando ejemplo: 356
# Procesando ejemplo: 357
# Procesando ejemplo: 358
# Procesando ejemplo: 359
# Procesando ejemplo: 360
# Procesando ejemplo: 361
# Procesando ejemplo: 362
# Procesando ejemplo: 363
# Procesando ejemplo: 364
# Procesando ejemplo: 365

# %%
# Representacion grafica del conjunto de datos
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.figure(figsize=(14, 7))
plt.plot(df_prep["CET"], df_prep["Mean TemperatureC"], c = "b")
plt.plot(df_prep["CET"], v_df, c = "g")

plt.ylabel("Temperatura", fontsize=14)
plt.xticks(['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01'], fontsize=11)
plt.yticks(fontsize=11)
plt.grid()

plt.show()

# %% [markdown]
# ## Exponentially Weighted Moving Average With Bias Correction

# %%
def ewma(theta, b=0.9):
    if len(theta) == 1:
        return b*0 + (1-b)*theta[-1]
    return b*ewma(theta[:-1]) + (1-b)*theta[-1]

# %%
# Aplicamos bias correction
import numpy as np

def apply_ewma_bias_corr(data, b=0.9):
    v_data = []
    for i in np.arange(1, len(data) + 1):
        print("\rProcesando ejemplo: {0}".format(i), end='')
        v_data.append(ewma(data[:i], b=b) / (1-b**i))
    return v_data

# %%
v_df_corr = apply_ewma_bias_corr(list(df_prep["Mean TemperatureC"]))
# Out:
# Procesando ejemplo: 365

# %%
# Representacion grafica del conjunto de datos
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plt.figure(figsize=(14, 7))

plt.plot(df_prep["CET"], df_prep["Mean TemperatureC"], c="b")
plt.plot(df_prep["CET"], v_df_corr, c="r")

plt.ylabel("Temperatura", fontsize=14)
plt.xticks(['2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12', '2016-01'])
plt.grid()

plt.show()
